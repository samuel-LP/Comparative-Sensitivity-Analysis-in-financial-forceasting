# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import sys

sys.path.append("../../scripts")
from XGBoost import PortfolioPredictionXGBoost_value
from LSTM_utils import compute_errors

# %% [markdown]
# # Import des données

# %%
titres = {"Amazon": pd.read_csv("../../data/AMZN.csv"),
          "Berkshire": pd.read_csv("../../data/BRK-B.csv"),
          "Google": pd.read_csv("../../data/GOOG.csv"),
          "Microsoft": pd.read_csv("../../data/MSFT.csv"),
          "Exxon": pd.read_csv("../../data/XOM.csv")}

# %% [markdown]
# # Modélisation

# %%
XGB = PortfolioPredictionXGBoost_value(titres, 
                                       window_size = 30, 
                                       horizon_prev = 7, 
                                       test_size = 0.8)

# %%
predictions, ptf_avg = XGB.predict_avg_portfolio()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 predictions, ptf_avg = XGB.predict_avg_portfolio()
#
# File ~/Documents/École/Université/M2/M2_S1/finance_quant/forecast_horizon/../scripts/XGBoost.py:85, in PortfolioPredictionXGBoost_value.predict_avg_portfolio(self)
#      83 def predict_avg_portfolio(self):
# ---> 85     self.predict_portfolio()
#      86     self.compute_portfolio()
#      88     return self.predictions_dic, self.portfolio_avg_predictions
#
# File ~/Documents/École/Université/M2/M2_S1/finance_quant/forecast_horizon/../scripts/XGBoost.py:63, in PortfolioPredictionXGBoost_value.predict_portfolio(self)
#      60 self.predictions_dic = {}
#      62 for key in tqdm(self.stock_dict):
# ---> 63     self.predictions_dic[key] = self.XG_boost_rolling_window(self.stock_dict[key])
#      64     self.predictions_dic[key] = self.compute_stock_returns(self.predictions_dic[key])
#
# File ~/Documents/École/Université/M2/M2_S1/finance_quant/forecast_horizon/../scripts/XGBoost.py:30, in PortfolioPredictionXGBoost_value.XG_boost_rolling_window(self, stock)
#      23 test = stock[end:end + self.horizon_prev].copy()
#      25 model = XGBRegressor(n_estimators=400,
#      26                      max_depth=30,
#      27                      learning_rate=0.01,
#      28                      verbosity=0)
# ---> 30 model.fit(train.drop(features_to_drop, axis=1), train['Target'])
#      32 pred = model.predict(test.drop(['Date', 'Target'], axis=1))
#      33 predictions.append(pred)
#
# File ~/Documents/École/Université/M2/M2_S1/finance_quant/venv/lib/python3.9/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File ~/Documents/École/Université/M2/M2_S1/finance_quant/venv/lib/python3.9/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~/Documents/École/Université/M2/M2_S1/finance_quant/venv/lib/python3.9/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~/Documents/École/Université/M2/M2_S1/finance_quant/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['Adj Close'] not found in axis"

# %% [markdown]
# # Résultats

# %%
for key, value in predictions.items() :
    fig = plt.figure(figsize=(12, 6))
    
    # Plot the 'Close' values
    plt.plot(value.Date, value['Close'], label='réel')
    plt.fill_between(value.Date, value['Close'], alpha=0.3)
    
    # Plot the 'Prediction' values
    plt.plot(value.Date, value['Prediction'], label='prédit')
    plt.fill_between(value.Date, value['Prediction'], alpha=0.3)
    
    # Set the title and axis labels
    plt.title(f"Évolution de la valeur de {key}")
    plt.xlabel('Date')
    plt.ylabel('Valeur')
    
    # Add a legend
    plt.legend()
    
    # Show the plot
    plt.show()

# %%
fig = plt.figure(figsize=(12, 6))

plt.plot(ptf_avg.Date, ptf_avg['Predicted_Portfolio_Value'], label='Predicted')
plt.fill_between(ptf_avg.Date, ptf_avg['Predicted_Portfolio_Value'], alpha=0.3)

plt.plot(ptf_avg.Date, ptf_avg['Real_Portfolio_Value'], label='Real')
plt.fill_between(ptf_avg.Date, ptf_avg['Real_Portfolio_Value'], alpha=0.3)

plt.title(f"Portfolio Value Evolution - 7 days forecast horizon")
plt.xlabel('Date')
plt.ylabel('Value')

plt.legend()
plt.show()

# %% [markdown]
# # Erreurs

# %%
errors = compute_errors(predictions, ptf_avg)

# %%
errors
# Out:
#                     MSE        RMSE         MAE
# Portfolio  13636.120341  116.773800  103.829164
# Amazon        62.505484    7.906041    5.414876
# Berkshire     90.291007    9.502158    6.559662
# Google        34.259267    5.853142    4.435546
# Microsoft    145.156068   12.048073    8.917668
# Exxon         17.655796    4.201880    3.171367
